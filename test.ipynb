# %%
import investpy

# %%
news = investpy.news.economic_calendar()

# %%
news
# Out:
#         id        date     time         zone currency importance  \
# 0      216  04/10/2024  All Day        china     None       None
# 1      216  04/10/2024  All Day        china     None       None
# 2   507601  04/10/2024    03:30    hong kong      HKD        low
# 3   507603  04/10/2024    04:00  philippines      PHP        low
# 4   507604  04/10/2024    04:00  philippines      PHP        low
# ..     ...         ...      ...          ...      ...        ...
# 86  508631  04/10/2024    22:30        japan      JPY     medium
# 87  508640  04/10/2024    22:30  new zealand      NZD        low
# 88  508642  04/10/2024    22:30    euro zone      EUR     medium
# 89     216  04/10/2024  All Day        china     None       None
# 90     216  04/10/2024  All Day        china     None       None
#
#                                             event actual forecast previous
# 0                            China - National Day   None     None     None
# ...
